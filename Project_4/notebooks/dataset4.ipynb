# %% [markdown]
# - `loc()` & `iloc()` , set values to rows, columns and cell or cells

# %%
import pandas as pd
import math
sci = pd.read_csv("../data/salaries-distribution.csv")

sci.loc[4:7, ['industry', 'experience_years', 'salary_usd']]

sci.iloc[4:9, 0:4]

sci.value_counts('industry')

# sci.loc[0, :] = math.nan                to set a row as NaN
sci.loc[75, ['location']] = 'Indian'        #to set a value in a cell

# condition = sci['experience_years'] > 15
# sci.loc[condition, ['industry']] = 'Yash'         this sets the value conditionally

sci
# Out:
#     employee_id    industry  experience_years  salary_usd  location  \
# 0             1     Finance                 0      119914     Urban
# 1             2  Healthcare                23       97545     Rural
# 2             3     Finance                18      183176     Urban
# 3             4     Finance                 6       86226     Rural
# 4             5  Technology                17      110606     Rural
# ..          ...         ...               ...         ...       ...
# 75           76  Technology                11       96176    Indian
# 76           77  Technology                 9      150724     Urban
# 77           78   Education                21       82868     Rural
# 78           79      Retail                24      109264     Rural
# 79           80   Education                 5       55812  Suburban
#
#    education_level
# 0           Master
# 1      High School
# 2              PhD
# 3         Bachelor
# 4         Bachelor
# ..             ...
# 75        Bachelor
# 76          Master
# 77        Bachelor
# 78             PhD
# 79        Bachelor
#
# [80 rows x 6 columns]
