# %%
# https://www.football-data.co.uk/mmz4281/2526/SC0.csv
# https://www.football-data.co.uk/mmz4281/2526/SC1.csv
# https://www.football-data.co.uk/mmz4281/2526/SC2.csv
# https://www.football-data.co.uk/mmz4281/2425/SC0.csv
#  
# Second_Project/data/AdventureWorks Product Categories Lookup.csv
import pandas as pd
root_url = 'https://www.football-data.co.uk/mmz4281/'

all_dataframes = []

print(len(all_dataframes))
year = 2324

for y in range(0, 3):
    for s in range(0, 4):
        url = f'{root_url}{year}/SC{s}.csv'
        # print(url)
        df = pd.read_csv(url)
        all_dataframes.append(df)
        df.to_csv(f'../data/{year}_{s}.csv')
    year = year + 101

print(len(all_dataframes))
all_dataframes[0]

# %%
import pandas as pd
df = pd.read_csv('../data/2324_0.csv')

df.rename(columns={'Unnamed: 0': 'index'}, inplace=True)
df
# Out:
#      index  Div        Date   Time      HomeTeam      AwayTeam  FTHG  FTAG  \
# 0        0  SC0  05/08/2023  12:30        Celtic   Ross County     4     2
# 1        1  SC0  05/08/2023  15:00        Dundee    Motherwell     1     1
# 2        2  SC0  05/08/2023  15:00    Livingston      Aberdeen     0     0
# 3        3  SC0  05/08/2023  15:00  St Johnstone        Hearts     0     2
# 4        4  SC0  05/08/2023  17:15    Kilmarnock       Rangers     1     0
# ..     ...  ...         ...    ...           ...           ...   ...   ...
# 223    223  SC0  18/05/2024  12:30        Dundee    Kilmarnock     1     1
# 224    224  SC0  18/05/2024  12:30        Hearts       Rangers     3     3
# 225    225  SC0  19/05/2024  15:00    Livingston     Hibernian     1     1
# 226    226  SC0  19/05/2024  15:00    Motherwell  St Johnstone     1     2
# 227    227  SC0  19/05/2024  15:00   Ross County      Aberdeen     2     2
#
#     FTR  HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     H     3  ...      4.18 -3.00     1.93      1.93   1.96   1.91     2.19
# 1     D     0  ...      1.66 -0.25     1.98      1.88   2.04   1.88     2.07
# 2     D     0  ...      1.69  0.00     1.95      1.90   2.03   1.88     2.04
# 3     A     0  ...      1.73  0.25     2.03      1.83   2.03   1.88     2.11
# 4     H     0  ...      2.21  1.25     2.03      1.83   2.04   1.87     2.09
# ..   ..   ...  ...       ...   ...      ...       ...    ...    ...      ...
# 223   D     1  ...      2.17 -0.25     2.05      1.80   2.13   1.79     2.14
# 224   D     1  ...      2.94  0.75     1.78      2.03   1.84   2.06     1.97
# 225   D     0  ...      2.44  0.75     1.85      2.00   1.88   2.03     1.90
# 226   A     0  ...      2.00 -0.25     1.90      1.95   1.93   1.98     2.06
# 227   D     1  ...      2.26 -0.25     2.03      1.83   2.05   1.86     2.07
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.95     1.97     1.84
# 1       1.93     1.97     1.85
# 2       1.95     1.97     1.85
# 3       1.88     2.01     1.80
# 4       1.90     1.97     1.84
# ..       ...      ...      ...
# 223     1.86     1.99     1.81
# 224     2.13     1.87     1.94
# 225     2.03     1.85     1.95
# 226     2.02     1.91     1.89
# 227     1.89     2.00     1.81
#
# [228 rows x 107 columns]
