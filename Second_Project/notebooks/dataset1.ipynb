# %%
import pandas as pd
import numpy as np


df = pd.DataFrame({
    "name": ["Yash", "Aman", "Vedant"],
    "age": [21,22, 13]
}, index= ["row1", "row2", "row3"])

df2 = pd.DataFrame(np.random.rand(3, 3), columns=["A", "B", "C"])
print(df)
print(df2)
# Out:
#         name  age
# row1    Yash   21
# row2    Aman   22
# row3  Vedant   13
#           A         B         C
# 0  0.292417  0.334940  0.459119
# 1  0.867602  0.003381  0.867101
# 2  0.223921  0.343984  0.081860
