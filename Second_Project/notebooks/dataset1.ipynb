# %%
import pandas as pd
import numpy as np


df = pd.DataFrame({
    "name": ["Yash", "Aman", "Vedant"],
    "age": [21,22, 13]
}, index= ["row1", "row2", "row3"])

df2 = pd.DataFrame(np.random.rand(3, 3), columns=["A", "B", "C"])

print(df)
print(df2)

data = np.random.rand(4, 2)
df3 = pd.DataFrame(data)

print(df3)

# %%
import pandas as pd

df_csv = pd.read_csv('../data/AdventureWorks Product Lookup.csv')
# df_csv
print("length of dataframe is: ", len(df_csv))
print("Highest index of df is: ", max(df_csv))
print("Lowest index of df is: ", min(df_csv))
print("typeof df is: ", type(df_csv))

# %%
df_trim = df_csv.filter(like='Product')
df_trim

# %%
import numpy as np
import pandas as pd
df_csv['New Column'] = 70   #the values 70 copies to the entire rows
df_csv

lang = np.random.randint(1, 100, size=293)
df_csv['New Column'] = lang   #this gives random whole numbers to the column 
df_csv
